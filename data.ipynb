# %%
import json
import sqlite3
import glob

files = glob.glob(r"data\processed\processed_raw_videos_*.json")
file_path = max(files)

with open(file_path, "r", encoding="utf-8") as file:
    data = json.load(file)

# %%
type(data)
for key in data:
    print(key)
# Out:
# videos
# comments

# %%
data.keys()
# Out:
# dict_keys(['videos', 'comments'])

# %%
db_path = r"data\youtube_pipeline.db"

conn = sqlite3.connect(db_path)
cursor = conn.cursor()

# %%
cursor.execute("SELECT * FROM sqlite_master WHERE type='table';")

tables = cursor.fetchall()
print(tables)
# Out:
# [('table', 'videos', 'videos', 2, 'CREATE TABLE videos (\n                video_id      TEXT PRIMARY KEY,\n                title         TEXT,\n                channel_name  TEXT,\n                channel_id    TEXT,\n                published_at  TEXT,\n                description   TEXT,\n                view_count    INTEGER DEFAULT 0,\n                like_count    INTEGER DEFAULT 0,\n                comment_count INTEGER DEFAULT 0\n            )'), ('table', 'comments', 'comments', 4, 'CREATE TABLE comments (\n                id            INTEGER PRIMARY KEY AUTOINCREMENT,\n                video_id      TEXT,\n                author        TEXT,\n                text          TEXT,\n                published_at  TEXT,\n                FOREIGN KEY (video_id) REFERENCES videos(video_id)\n            )'), ('table', 'sqlite_sequence', 'sqlite_sequence', 5, 'CREATE TABLE sqlite_sequence(name,seq)')]

# %%
import pandas as pd

df = pd.read_sql_query("SELECT * FROM videos;", conn)

df.head()
# Out:
#       video_id                                              title  \
# 0  1XECx2DCW2A  كـــرداســـة | أحداث كرداسة.. ملحمة البطولة وا...
# 1  DqxcsA3mDLw  "إنت وظباطك... اخلوا القسم حالًا" 😳 فصل من أصع...
# 2  XXMqOnGIByo  مــــزاج دلـــيفري |  كل حاجة كانت متوفرة.. وا...
# 3  zzXaIn_h5D8  مزاج دليفري | كل طلب كان ليه سعر.. لكن اللي كا...
# 4  ceU4H-0J_Io  الـبسـاتين | خمس أرواح راحت.. بس الجريمة دي بد...
#
#          channel_name                channel_id          published_at  \
# 0  Podcast El Masyada  UCcjo-PzMKtCD0jX8d_7X7vQ  2026-06-30T20:00:06Z
# 1  Podcast El Masyada  UCcjo-PzMKtCD0jX8d_7X7vQ  2026-06-29T21:36:30Z
# 2  Podcast El Masyada  UCcjo-PzMKtCD0jX8d_7X7vQ  2026-06-26T18:00:06Z
# 3  Podcast El Masyada  UCcjo-PzMKtCD0jX8d_7X7vQ  2026-06-25T10:31:54Z
# 4  Podcast El Masyada  UCcjo-PzMKtCD0jX8d_7X7vQ  2026-06-23T18:00:06Z
#
#                                          description  view_count  like_count  \
# 0  كـــرداســـة | قصة حقيقية من ملفات ظابط مباحث ...        3557         387
# 1  شاهد الحلقات الكاملة من بودكاست المصيدة من هنا...        8503         503
# 2  مــــزاج دلـــيفري |  قصة حقيقية من ملفات ظابط...      162546        5727
# 3  شاهد الحلقات الكاملة من بودكاست المصيدة من هنا...        7295         303
# 4  الـبسـاتين | قصة حقيقية من ملفات ظابط مباحث\n\...      122303        4715
#
#    comment_count
# 0             94
# 1             49
# 2           1051
# 3             24
# 4            544

# %%
conn = sqlite3.connect(r"C:\Users\ITHives\Desktop\youtube-pipeline\data\youtube_pipeline.db")

tables = pd.read_sql_query(
    "SELECT name FROM sqlite_master WHERE type='table';",
    conn
)

print(tables)
# Out:
#               name
# 0           videos
# 1         comments
# 2  sqlite_sequence

# %%
for table in tables["name"]:
    df = pd.read_sql_query(f"SELECT * FROM {table}", conn)
    df.to_csv(f"{table}.csv", index=False, encoding="utf-8-sig")

conn.close()

# %%
import os
import sqlite3
import pandas as pd

# الاتصال بقاعدة البيانات
db_path = r"C:\Users\ITHives\Desktop\youtube-pipeline\data\youtube_pipeline.db"
conn = sqlite3.connect(db_path)

# إنشاء مجلد csv إذا لم يكن موجودًا
output_folder = r"data\csv"
os.makedirs(output_folder, exist_ok=True)

# جلب أسماء الجداول
tables = pd.read_sql_query(
    "SELECT name FROM sqlite_master WHERE type='table';",
    conn
)

# تحويل كل جدول إلى CSV
for table in tables["name"]:
    df = pd.read_sql_query(f"SELECT * FROM {table}", conn)
    output_path = os.path.join(output_folder, f"{table}.csv")
    df.to_csv(output_path, index=False, encoding="utf-8-sig")
    print(f"Saved: {output_path}")

conn.close()
# Out:
# Saved: data\csv\videos.csv
# Saved: data\csv\comments.csv
# Saved: data\csv\sqlite_sequence.csv

# %%
comments = pd.read_csv("data/csv/comments.csv")
comments.head()
# Out:
#    id     video_id            author  \
# 0   1  1XECx2DCW2A    @ahmedramzy597
# 1   2  1XECx2DCW2A  @amanybahgat7288
# 2   3  1XECx2DCW2A   @مهاابوغالى-ح2ل
# 3   4  1XECx2DCW2A       @GadEid-i1y
# 4   5  1XECx2DCW2A   @jemmyadams5466
#
#                                                 text          published_at
# 0  الواحد عمره ما كان يتخيل ان المصريين يقتلوا بع...  2026-06-30T20:59:07Z
# 1              رجال مصر اللى حاميين شرفنا و ارواحنا.  2026-06-30T20:58:39Z
# 2  الله يرحم شهداء وطننا مصر الحبيبه     ياريت قر...  2026-06-30T20:57:54Z
# 3  امجد بيه مافيش ولا عمليه فشلت معاكم والمجرم طل...  2026-06-30T20:57:40Z
# 4                             Great work 🎉🎉 New York  2026-06-30T20:57:06Z

# %%
comments.describe()
# Out:
#                 id
# count  8726.000000
# mean   4363.500000
# std    2519.123558
# min       1.000000
# 25%    2182.250000
# 50%    4363.500000
# 75%    6544.750000
# max    8726.000000

# %%
comments.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8726 entries, 0 to 8725
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            8726 non-null   int64
#  1   video_id      8726 non-null   str
#  2   author        8726 non-null   str
#  3   text          8726 non-null   str
#  4   published_at  8726 non-null   str
# dtypes: int64(1), str(4)
# memory usage: 341.0 KB

# %%
videos = pd.read_csv("data/csv/videos.csv")
videos.head()
# Out:
#       video_id                                              title  \
# 0  1XECx2DCW2A  كـــرداســـة | أحداث كرداسة.. ملحمة البطولة وا...
# 1  DqxcsA3mDLw  "إنت وظباطك... اخلوا القسم حالًا" 😳 فصل من أصع...
# 2  XXMqOnGIByo  مــــزاج دلـــيفري |  كل حاجة كانت متوفرة.. وا...
# 3  zzXaIn_h5D8  مزاج دليفري | كل طلب كان ليه سعر.. لكن اللي كا...
# 4  ceU4H-0J_Io  الـبسـاتين | خمس أرواح راحت.. بس الجريمة دي بد...
#
#          channel_name                channel_id          published_at  \
# 0  Podcast El Masyada  UCcjo-PzMKtCD0jX8d_7X7vQ  2026-06-30T20:00:06Z
# 1  Podcast El Masyada  UCcjo-PzMKtCD0jX8d_7X7vQ  2026-06-29T21:36:30Z
# 2  Podcast El Masyada  UCcjo-PzMKtCD0jX8d_7X7vQ  2026-06-26T18:00:06Z
# 3  Podcast El Masyada  UCcjo-PzMKtCD0jX8d_7X7vQ  2026-06-25T10:31:54Z
# 4  Podcast El Masyada  UCcjo-PzMKtCD0jX8d_7X7vQ  2026-06-23T18:00:06Z
#
#                                          description  view_count  like_count  \
# 0  كـــرداســـة | قصة حقيقية من ملفات ظابط مباحث ...        3557         387
# 1  شاهد الحلقات الكاملة من بودكاست المصيدة من هنا...        8503         503
# 2  مــــزاج دلـــيفري |  قصة حقيقية من ملفات ظابط...      162546        5727
# 3  شاهد الحلقات الكاملة من بودكاست المصيدة من هنا...        7295         303
# 4  الـبسـاتين | قصة حقيقية من ملفات ظابط مباحث\n\...      122303        4715
#
#    comment_count
# 0             94
# 1             49
# 2           1051
# 3             24
# 4            544

# %%
videos.describe()
# Out:
#          view_count    like_count  comment_count
# count  6.000000e+01     60.000000      60.000000
# mean   2.916039e+05  10631.566667     700.483333
# std    3.535916e+05  11030.444849     684.774081
# min    3.111000e+03    197.000000       8.000000
# 25%    2.694200e+04   1406.500000      65.000000
# 50%    2.023010e+05   8543.000000     641.500000
# 75%    3.456585e+05  13718.750000     945.250000
# max    1.405427e+06  39048.000000    2987.000000

# %%
videos.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       60 non-null     str
#  1   title          60 non-null     str
#  2   channel_name   60 non-null     str
#  3   channel_id     60 non-null     str
#  4   published_at   60 non-null     str
#  5   description    48 non-null     str
#  6   view_count     60 non-null     int64
#  7   like_count     60 non-null     int64
#  8   comment_count  60 non-null     int64
# dtypes: int64(3), str(6)
# memory usage: 4.3 KB

# %%
videos["published_at"] = pd.to_datetime(videos["published_at"])

# %%
videos["day_name"] = videos["published_at"].dt.day_name()

# %%
day_counts = (
    videos["day_name"]
    .value_counts()
    .reindex([
        "Monday",
        "Tuesday",
        "Wednesday",
        "Thursday",
        "Friday",
        "Saturday",
        "Sunday"
    ])
)

# %% [markdown]
# **Number of Videos Published by Day of Week**

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

day_counts.plot(kind="bar")

plt.title("Number of Videos Published by Day of Week")
plt.xlabel("Day")
plt.ylabel("Number of Videos")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# **Views vs Likes (Scatter Plot)**

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

plt.scatter(
    videos["view_count"] / 1_000_000,
    videos["like_count"] / 1_000,
    alpha=0.7
)

plt.title("Views vs Likes")
plt.xlabel("Views (Millions)")
plt.ylabel("Likes (Thousands)")

plt.grid(True)
plt.show()

# %% [markdown]
# **Average Views per Channel**

# %%
avg_views = (
    videos.groupby("channel_name")["view_count"]
    .mean()
    .sort_values(ascending=False)
)


plt.figure(figsize=(5, 4))

avg_views.plot(kind="bar")

plt.title("Average Views per Channel")
plt.xlabel("Channel")
plt.ylabel("Average Views")

plt.xticks(rotation=45, ha="right")

plt.grid(axis="y", linestyle="--", alpha=0.5)

plt.tight_layout()
plt.show()
